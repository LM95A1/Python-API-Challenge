# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 604

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mukah
# City not found. Skipping...
# Processing Record 2 of Set 1 | cobija
# Processing Record 3 of Set 1 | lihue
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | ribeira grande
# Processing Record 7 of Set 1 | polyarnyy
# Processing Record 8 of Set 1 | puerto natales
# Processing Record 9 of Set 1 | murghob
# Processing Record 10 of Set 1 | adamstown
# Processing Record 11 of Set 1 | port-aux-francais
# Processing Record 12 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 13 of Set 1 | waitangi
# Processing Record 14 of Set 1 | kasangulu
# Processing Record 15 of Set 1 | tolanaro
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | zaio
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | blackmans bay
# Processing Record 20 of Set 1 | iqaluit
# Processing Record 21 of Set 1 | codrington
# Processing Record 22 of Set 1 | campbell river
# Processing Record 23 of Set 1 | tiksi
# Processing Record 24 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 25 of Set 1 | margaret river
# Processing Record 26 of Set 1 | slavyanka
# Processing Record 27 of Set 1 | ust-nera
# Processing Record 28 of Set 1 | olonkinbyen
# Processing Record 29 of Set 1 | edinburgh of the seven seas
# Processing Record 30 of Set 1 | saipan
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | brokopondo
# Processing Record 33 of Set 1 | kegeyli shahar
# Processing Record 34 of Set 1 | nova sintra
# Processing Record 35 of Set 1 | yuza
# Processing Record 36 of Set 1 | summerside
# Processing Record 37 of Set 1 | vilyuchinsk
# Processing Record 38 of Set 1 | quellon
# Processing Record 39 of Set 1 | grytviken
# Processing Record 40 of Set 1 | port mathurin
# Processing Record 41 of Set 1 | nagqu
# Processing Record 42 of Set 1 | touros
# Processing Record 43 of Set 1 | saint-pierre
# Processing Record 44 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | mount isa
# Processing Record 47 of Set 1 | ciudad lazaro cardenas
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | hamilton
# Processing Record 50 of Set 1 | bilibino
# Processing Record 0 of Set 2 | puerto ayora
# Processing Record 1 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 2 of Set 2 | tymovskoye
# Processing Record 3 of Set 2 | pader palwo
# Processing Record 4 of Set 2 | lensk
# Processing Record 5 of Set 2 | constantia
# Processing Record 6 of Set 2 | puerto santa
# Processing Record 7 of Set 2 | mata-utu
# Processing Record 8 of Set 2 | invercargill
# Processing Record 9 of Set 2 | kingston
# Processing Record 10 of Set 2 | upington
# Processing Record 11 of Set 2 | papatowai
# Processing Record 12 of Set 2 | atafu village
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | gubkinskiy
# Processing Record 15 of Set 2 | qaqortoq
# Processing Record 16 of Set 2 | papao
# Processing Record 17 of Set 2 | kodiak
# Processing Record 18 of Set 2 | rasht
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | enewetak
# Processing Record 21 of Set 2 | flin flon
# Processing Record 22 of Set 2 | duzce
# Processing Record 23 of Set 2 | greenville
# Processing Record 24 of Set 2 | fort bragg
# Processing Record 25 of Set 2 | westport
# Processing Record 26 of Set 2 | belyy yar
# Processing Record 27 of Set 2 | acarau
# Processing Record 28 of Set 2 | egersund
# Processing Record 29 of Set 2 | wailua homesteads
# Processing Record 30 of Set 2 | ilha de mocambique
# Processing Record 31 of Set 2 | makueni boma
# Processing Record 32 of Set 2 | lethem
# Processing Record 33 of Set 2 | calama
# Processing Record 34 of Set 2 | ijuw
# City not found. Skipping...
# Processing Record 35 of Set 2 | lebu
# Processing Record 36 of Set 2 | ruwandiz
# Processing Record 37 of Set 2 | whitehorse
# Processing Record 38 of Set 2 | powell river
# Processing Record 39 of Set 2 | isafjordur
# Processing Record 40 of Set 2 | novoishimskiy
# Processing Record 41 of Set 2 | sinabang
# Processing Record 42 of Set 2 | ola
# Processing Record 43 of Set 2 | malango
# Processing Record 44 of Set 2 | peace river
# Processing Record 45 of Set 2 | callao
# Processing Record 46 of Set 2 | alterosa
# Processing Record 47 of Set 2 | hawaiian paradise park
# Processing Record 48 of Set 2 | kirkwood
# Processing Record 49 of Set 2 | klyuchi
# Processing Record 0 of Set 3 | yurty
# Processing Record 1 of Set 3 | college
# Processing Record 2 of Set 3 | port elizabeth
# Processing Record 3 of Set 3 | labytnangi
# Processing Record 4 of Set 3 | holualoa
# Processing Record 5 of Set 3 | mount gambier
# Processing Record 6 of Set 3 | badger
# Processing Record 7 of Set 3 | jinchang
# Processing Record 8 of Set 3 | kailua-kona
# Processing Record 9 of Set 3 | katsuren-haebaru
# Processing Record 10 of Set 3 | aykhal
# Processing Record 11 of Set 3 | stanley
# Processing Record 12 of Set 3 | crane
# Processing Record 13 of Set 3 | saint-philippe
# Processing Record 14 of Set 3 | neryungri
# Processing Record 15 of Set 3 | hami
# Processing Record 16 of Set 3 | salto
# Processing Record 17 of Set 3 | freeport
# Processing Record 18 of Set 3 | west island
# Processing Record 19 of Set 3 | formosa do rio preto
# Processing Record 20 of Set 3 | perry
# Processing Record 21 of Set 3 | mont-dore
# Processing Record 22 of Set 3 | kourou
# Processing Record 23 of Set 3 | khromtau
# Processing Record 24 of Set 3 | dakhla
# Processing Record 25 of Set 3 | sitka
# Processing Record 26 of Set 3 | mo i rana
# Processing Record 27 of Set 3 | hermosillo
# Processing Record 28 of Set 3 | mahina
# Processing Record 29 of Set 3 | narasannapeta
# Processing Record 30 of Set 3 | kavieng
# Processing Record 31 of Set 3 | fortuna
# Processing Record 32 of Set 3 | rio grande
# Processing Record 33 of Set 3 | el calafate
# Processing Record 34 of Set 3 | ancud
# Processing Record 35 of Set 3 | kununurra
# Processing Record 36 of Set 3 | matsue
# Processing Record 37 of Set 3 | afaahiti
# Processing Record 38 of Set 3 | hoa binh
# Processing Record 39 of Set 3 | sao paulo do potengi
# Processing Record 40 of Set 3 | trujillo
# Processing Record 41 of Set 3 | tekane
# City not found. Skipping...
# Processing Record 42 of Set 3 | buloh kasap
# Processing Record 43 of Set 3 | tanjung selor
# City not found. Skipping...
# Processing Record 44 of Set 3 | palmer
# Processing Record 45 of Set 3 | esmeraldas
# Processing Record 46 of Set 3 | san patricio
# Processing Record 47 of Set 3 | kavaratti
# Processing Record 48 of Set 3 | baiculesti
# Processing Record 49 of Set 3 | port lincoln
# Processing Record 0 of Set 4 | iskateley
# Processing Record 1 of Set 4 | nouadhibou
# Processing Record 2 of Set 4 | puerto baquerizo moreno
# Processing Record 3 of Set 4 | sungai petani
# Processing Record 4 of Set 4 | tralee
# Processing Record 5 of Set 4 | hauterive
# Processing Record 6 of Set 4 | san pedro pochutla
# Processing Record 7 of Set 4 | tianpeng
# Processing Record 8 of Set 4 | kiruna
# Processing Record 9 of Set 4 | yaren
# Processing Record 10 of Set 4 | t'ongch'on-up
# Processing Record 11 of Set 4 | guangming
# Processing Record 12 of Set 4 | tazovsky
# Processing Record 13 of Set 4 | lata
# Processing Record 14 of Set 4 | cabedelo
# Processing Record 15 of Set 4 | skovorodino
# Processing Record 16 of Set 4 | hun
# Processing Record 17 of Set 4 | kassala
# Processing Record 18 of Set 4 | alo
# Processing Record 19 of Set 4 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 20 of Set 4 | igarka
# Processing Record 21 of Set 4 | yelm
# Processing Record 22 of Set 4 | santa cruz
# Processing Record 23 of Set 4 | sisimiut
# Processing Record 24 of Set 4 | kutina
# Processing Record 25 of Set 4 | sinan
# Processing Record 26 of Set 4 | punta arenas
# Processing Record 27 of Set 4 | thompson
# Processing Record 28 of Set 4 | dungarpur
# Processing Record 29 of Set 4 | tsiombe
# Processing Record 30 of Set 4 | winnemucca
# Processing Record 31 of Set 4 | kiunga
# Processing Record 32 of Set 4 | lucas
# Processing Record 33 of Set 4 | longyearbyen
# Processing Record 34 of Set 4 | demba
# Processing Record 35 of Set 4 | ilulissat
# Processing Record 36 of Set 4 | dunedin
# Processing Record 37 of Set 4 | hobyo
# Processing Record 38 of Set 4 | aasiaat
# Processing Record 39 of Set 4 | colonia
# Processing Record 40 of Set 4 | kitimat
# Processing Record 41 of Set 4 | port saint john's
# Processing Record 42 of Set 4 | skiathos
# Processing Record 43 of Set 4 | hadsund
# Processing Record 44 of Set 4 | leon
# Processing Record 45 of Set 4 | kyshtovka
# Processing Record 46 of Set 4 | l'alcora
# Processing Record 47 of Set 4 | coquimbo
# Processing Record 48 of Set 4 | codo
# Processing Record 49 of Set 4 | itaituba
# Processing Record 0 of Set 5 | boa vista
# Processing Record 1 of Set 5 | poltavka
# Processing Record 2 of Set 5 | sodankyla
# Processing Record 3 of Set 5 | canar
# Processing Record 4 of Set 5 | happy valley-goose bay
# Processing Record 5 of Set 5 | souillac
# Processing Record 6 of Set 5 | kone
# Processing Record 7 of Set 5 | utrik
# Processing Record 8 of Set 5 | kristiansund
# Processing Record 9 of Set 5 | armacao de buzios
# Processing Record 10 of Set 5 | newman
# Processing Record 11 of Set 5 | jamestown
# Processing Record 12 of Set 5 | tomohon
# Processing Record 13 of Set 5 | nemuro
# Processing Record 14 of Set 5 | nakhon nayok
# Processing Record 15 of Set 5 | hermanus
# Processing Record 16 of Set 5 | saldanha
# Processing Record 17 of Set 5 | port isabel
# Processing Record 18 of Set 5 | vadso
# Processing Record 19 of Set 5 | fonadhoo
# City not found. Skipping...
# Processing Record 20 of Set 5 | udachny
# Processing Record 21 of Set 5 | princeville
# Processing Record 22 of Set 5 | olonets
# Processing Record 23 of Set 5 | masterton
# Processing Record 24 of Set 5 | vernal
# Processing Record 25 of Set 5 | la ronge
# Processing Record 26 of Set 5 | pimentel
# Processing Record 27 of Set 5 | worthington
# Processing Record 28 of Set 5 | vernon
# Processing Record 29 of Set 5 | kharan
# Processing Record 30 of Set 5 | villanueva
# Processing Record 31 of Set 5 | gora
# Processing Record 32 of Set 5 | hilo
# Processing Record 33 of Set 5 | kuanda
# Processing Record 34 of Set 5 | minas de marcona
# Processing Record 35 of Set 5 | tura
# Processing Record 36 of Set 5 | yuci
# Processing Record 37 of Set 5 | puerto lempira
# Processing Record 38 of Set 5 | nuuk
# Processing Record 39 of Set 5 | sao vicente
# Processing Record 40 of Set 5 | fredericksburg
# Processing Record 41 of Set 5 | baruun-urt
# Processing Record 42 of Set 5 | aktobe
# Processing Record 43 of Set 5 | kawthoung
# City not found. Skipping...
# Processing Record 44 of Set 5 | alice springs
# Processing Record 45 of Set 5 | firuzabad
# Processing Record 46 of Set 5 | siracusa
# Processing Record 47 of Set 5 | san jose del guaviare
# Processing Record 48 of Set 5 | san antonio de pale
# Processing Record 49 of Set 5 | amahai
# Processing Record 0 of Set 6 | serov
# Processing Record 1 of Set 6 | aitape
# Processing Record 2 of Set 6 | gebeit
# Processing Record 3 of Set 6 | angra do heroismo
# Processing Record 4 of Set 6 | bocas del toro
# Processing Record 5 of Set 6 | bokoro
# Processing Record 6 of Set 6 | kapuskasing
# Processing Record 7 of Set 6 | artsyz
# Processing Record 8 of Set 6 | antsohimbondrona
# City not found. Skipping...
# Processing Record 9 of Set 6 | qiongshan
# Processing Record 10 of Set 6 | planaltina
# Processing Record 11 of Set 6 | bamboo flat
# Processing Record 12 of Set 6 | bichura
# Processing Record 13 of Set 6 | tenextepango
# City not found. Skipping...
# Processing Record 14 of Set 6 | marang
# Processing Record 15 of Set 6 | pillaro
# Processing Record 16 of Set 6 | den burg
# Processing Record 17 of Set 6 | maun
# Processing Record 18 of Set 6 | tiassale
# Processing Record 19 of Set 6 | kiiminki
# Processing Record 20 of Set 6 | werota
# Processing Record 21 of Set 6 | kapa'a
# Processing Record 22 of Set 6 | porto murtinho
# Processing Record 23 of Set 6 | zhashkiv
# Processing Record 24 of Set 6 | les cayes
# Processing Record 25 of Set 6 | nosy varika
# Processing Record 26 of Set 6 | fort mcmurray
# Processing Record 27 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 28 of Set 6 | vorgashor
# Processing Record 29 of Set 6 | akonolinga
# Processing Record 30 of Set 6 | salinas
# Processing Record 31 of Set 6 | choibalsan
# Processing Record 32 of Set 6 | puerto aysen
# Processing Record 33 of Set 6 | chonchi
# Processing Record 34 of Set 6 | eyl
# Processing Record 35 of Set 6 | cabo san lucas
# Processing Record 36 of Set 6 | escalante
# Processing Record 37 of Set 6 | kulia village
# City not found. Skipping...
# Processing Record 38 of Set 6 | recreo
# Processing Record 39 of Set 6 | robbah
# Processing Record 40 of Set 6 | la'ie
# Processing Record 41 of Set 6 | susuman
# Processing Record 42 of Set 6 | puerto armuelles
# Processing Record 43 of Set 6 | penzance
# Processing Record 44 of Set 6 | phan thiet
# Processing Record 45 of Set 6 | vobkent shahri
# City not found. Skipping...
# Processing Record 46 of Set 6 | suoyarvi
# Processing Record 47 of Set 6 | kanchanaburi
# Processing Record 48 of Set 6 | alaghsas
# Processing Record 49 of Set 6 | trongsa
# Processing Record 0 of Set 7 | grand falls-windsor
# Processing Record 1 of Set 7 | nar'yan-mar
# Processing Record 2 of Set 7 | pisco
# Processing Record 3 of Set 7 | hasaki
# Processing Record 4 of Set 7 | stornoway
# Processing Record 5 of Set 7 | chorfa
# Processing Record 6 of Set 7 | yeniseysk
# Processing Record 7 of Set 7 | porto novo
# Processing Record 8 of Set 7 | rongelap
# Processing Record 9 of Set 7 | namibe
# Processing Record 10 of Set 7 | chichiriviche
# Processing Record 11 of Set 7 | misliyah
# Processing Record 12 of Set 7 | likiep
# Processing Record 13 of Set 7 | cafayate
# Processing Record 14 of Set 7 | camana
# Processing Record 15 of Set 7 | alofi
# Processing Record 16 of Set 7 | harper
# Processing Record 17 of Set 7 | talnakh
# Processing Record 18 of Set 7 | villa gesell
# Processing Record 19 of Set 7 | bull savanna
# Processing Record 20 of Set 7 | beau vallon
# Processing Record 21 of Set 7 | cockburn town
# Processing Record 22 of Set 7 | engenheiro beltrao
# Processing Record 23 of Set 7 | vakarai
# Processing Record 24 of Set 7 | keflavik
# Processing Record 25 of Set 7 | san luis de la loma
# Processing Record 26 of Set 7 | howrah
# Processing Record 27 of Set 7 | maubara
# City not found. Skipping...
# Processing Record 28 of Set 7 | oshawa
# Processing Record 29 of Set 7 | ushtobe
# Processing Record 30 of Set 7 | hadibu
# Processing Record 31 of Set 7 | aljezur
# Processing Record 32 of Set 7 | bam
# Processing Record 33 of Set 7 | bardai
# Processing Record 34 of Set 7 | karratha
# Processing Record 35 of Set 7 | robertsport
# Processing Record 36 of Set 7 | chegdomyn
# Processing Record 37 of Set 7 | gorshechnoye
# Processing Record 38 of Set 7 | yemetsk
# Processing Record 39 of Set 7 | kayangel
# Processing Record 40 of Set 7 | bairnsdale
# Processing Record 41 of Set 7 | lexington
# Processing Record 42 of Set 7 | nasugbu
# Processing Record 43 of Set 7 | wotho
# Processing Record 44 of Set 7 | genhe
# Processing Record 45 of Set 7 | balabac
# Processing Record 46 of Set 7 | carauari
# Processing Record 47 of Set 7 | akrehamn
# Processing Record 48 of Set 7 | mhamid
# Processing Record 49 of Set 7 | mogocha
# Processing Record 0 of Set 8 | dalandzadgad
# Processing Record 1 of Set 8 | lagoa
# Processing Record 2 of Set 8 | praia da vitoria
# Processing Record 3 of Set 8 | biarritz
# Processing Record 4 of Set 8 | del rio
# Processing Record 5 of Set 8 | pasighat
# Processing Record 6 of Set 8 | ugoofaaru
# Processing Record 7 of Set 8 | argo
# Processing Record 8 of Set 8 | vilyuysk
# Processing Record 9 of Set 8 | mejit
# Processing Record 10 of Set 8 | margate
# Processing Record 11 of Set 8 | uturoa
# Processing Record 12 of Set 8 | jurm
# Processing Record 13 of Set 8 | cochrane
# Processing Record 14 of Set 8 | sirte
# Processing Record 15 of Set 8 | port blair
# Processing Record 16 of Set 8 | villa luvianos
# Processing Record 17 of Set 8 | cosne-cours-sur-loire
# Processing Record 18 of Set 8 | fale old settlement
# Processing Record 19 of Set 8 | shahrak
# Processing Record 20 of Set 8 | lewistown
# Processing Record 21 of Set 8 | horta
# Processing Record 22 of Set 8 | novi grad
# Processing Record 23 of Set 8 | bitburg
# Processing Record 24 of Set 8 | pariaman
# Processing Record 25 of Set 8 | san jose village
# City not found. Skipping...
# Processing Record 26 of Set 8 | nhamunda
# Processing Record 27 of Set 8 | tokar
# Processing Record 28 of Set 8 | iowa park
# Processing Record 29 of Set 8 | phongsali
# Processing Record 30 of Set 8 | nyurba
# Processing Record 31 of Set 8 | aberdeen
# Processing Record 32 of Set 8 | kamaishi
# Processing Record 33 of Set 8 | isangel
# Processing Record 34 of Set 8 | hastings
# Processing Record 35 of Set 8 | kiama
# Processing Record 36 of Set 8 | lazaro cardenas
# Processing Record 37 of Set 8 | kajuru
# Processing Record 38 of Set 8 | kuloy
# Processing Record 39 of Set 8 | mossel bay
# Processing Record 40 of Set 8 | bubaque
# Processing Record 41 of Set 8 | marka
# Processing Record 42 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 8 | yakeshi
# Processing Record 44 of Set 8 | egilsstadir
# Processing Record 45 of Set 8 | dzhalagash
# Processing Record 46 of Set 8 | morehead city
# Processing Record 47 of Set 8 | noshiro
# Processing Record 48 of Set 8 | worland
# Processing Record 49 of Set 8 | makurazaki
# Processing Record 0 of Set 9 | hillsborough
# Processing Record 1 of Set 9 | cruzeiro do sul
# Processing Record 2 of Set 9 | severo-yeniseyskiy
# Processing Record 3 of Set 9 | okhotsk
# Processing Record 4 of Set 9 | kohat
# Processing Record 5 of Set 9 | assab
# Processing Record 6 of Set 9 | glace bay
# Processing Record 7 of Set 9 | sanctuary point
# Processing Record 8 of Set 9 | gadzhiyevo
# Processing Record 9 of Set 9 | portel
# Processing Record 10 of Set 9 | tual
# Processing Record 11 of Set 9 | lebowakgomo
# Processing Record 12 of Set 9 | sretensk
# Processing Record 13 of Set 9 | aldan
# Processing Record 14 of Set 9 | zhob
# Processing Record 15 of Set 9 | khorixas
# Processing Record 16 of Set 9 | chui
# Processing Record 17 of Set 9 | bata
# Processing Record 18 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 19 of Set 9 | pandan
# Processing Record 20 of Set 9 | chipinge
# Processing Record 21 of Set 9 | geraldton
# Processing Record 22 of Set 9 | novodvinsk
# Processing Record 23 of Set 9 | lyantor
# Processing Record 24 of Set 9 | fisterra
# Processing Record 25 of Set 9 | kelme
# Processing Record 26 of Set 9 | antofagasta
# Processing Record 27 of Set 9 | nukunonu
# City not found. Skipping...
# Processing Record 28 of Set 9 | moree
# Processing Record 29 of Set 9 | island harbour
# Processing Record 30 of Set 9 | verkhnevilyuysk
# Processing Record 31 of Set 9 | laguna
# Processing Record 32 of Set 9 | shush
# Processing Record 33 of Set 9 | kungur
# Processing Record 34 of Set 9 | west plains
# Processing Record 35 of Set 9 | luwuk
# Processing Record 36 of Set 9 | ilebo
# Processing Record 37 of Set 9 | puerto madero
# Processing Record 38 of Set 9 | yung shue wan
# Processing Record 39 of Set 9 | tabou
# Processing Record 40 of Set 9 | newport
# Processing Record 41 of Set 9 | illizi
# Processing Record 42 of Set 9 | jining
# Processing Record 43 of Set 9 | cururupu
# Processing Record 44 of Set 9 | betio village
# Processing Record 45 of Set 9 | mar''ina horka
# Processing Record 46 of Set 9 | pativilca
# Processing Record 47 of Set 9 | taoudenni
# Processing Record 48 of Set 9 | khamis mushait
# Processing Record 49 of Set 9 | ayden
# Processing Record 0 of Set 10 | ghardaia
# Processing Record 1 of Set 10 | howard springs
# Processing Record 2 of Set 10 | timimoun
# Processing Record 3 of Set 10 | gunjur
# Processing Record 4 of Set 10 | remire-montjoly
# Processing Record 5 of Set 10 | miles city
# Processing Record 6 of Set 10 | thunder bay
# Processing Record 7 of Set 10 | rancho palos verdes
# Processing Record 8 of Set 10 | gazipasa
# Processing Record 9 of Set 10 | kota belud
# Processing Record 10 of Set 10 | shimanovsk
# Processing Record 11 of Set 10 | xinqing
# Processing Record 12 of Set 10 | necochea
# Processing Record 13 of Set 10 | kijang
# Processing Record 14 of Set 10 | sa'dah
# Processing Record 15 of Set 10 | antonio enes
# Processing Record 16 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 17 of Set 10 | shumikha
# Processing Record 18 of Set 10 | amarillo
# Processing Record 19 of Set 10 | aioun
# Processing Record 20 of Set 10 | real
# Processing Record 21 of Set 10 | onega
# Processing Record 22 of Set 10 | nueve de julio
# Processing Record 23 of Set 10 | benguela
# Processing Record 24 of Set 10 | katima mulilo
# Processing Record 25 of Set 10 | brits
# Processing Record 26 of Set 10 | nguigmi
# Processing Record 27 of Set 10 | kodinsk
# Processing Record 28 of Set 10 | tobruk
# Processing Record 29 of Set 10 | goz beida
# Processing Record 30 of Set 10 | jaunpils
# Processing Record 31 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 32 of Set 10 | nampula
# Processing Record 33 of Set 10 | opuwo
# Processing Record 34 of Set 10 | sosnovo-ozerskoye
# Processing Record 35 of Set 10 | haiku-pauwela
# Processing Record 36 of Set 10 | taitung city
# Processing Record 37 of Set 10 | abu jibeha
# Processing Record 38 of Set 10 | anadyr
# Processing Record 39 of Set 10 | zahedan
# Processing Record 40 of Set 10 | luanda
# Processing Record 41 of Set 10 | creel
# Processing Record 42 of Set 10 | beyneu
# Processing Record 43 of Set 10 | fabens
# Processing Record 44 of Set 10 | kudahuvadhoo
# Processing Record 45 of Set 10 | tanumah
# Processing Record 46 of Set 10 | okha
# Processing Record 47 of Set 10 | ponta delgada
# Processing Record 48 of Set 10 | shengli
# Processing Record 49 of Set 10 | sussex
# Processing Record 0 of Set 11 | bida
# Processing Record 1 of Set 11 | columbus
# Processing Record 2 of Set 11 | namdrik
# Processing Record 3 of Set 11 | pacific grove
# Processing Record 4 of Set 11 | mizan teferi
# Processing Record 5 of Set 11 | redencao
# Processing Record 6 of Set 11 | semnan
# Processing Record 7 of Set 11 | la passe
# Processing Record 8 of Set 11 | zag
# Processing Record 9 of Set 11 | micheweni
# Processing Record 10 of Set 11 | puerto rico
# Processing Record 11 of Set 11 | cueibet
# City not found. Skipping...
# Processing Record 12 of Set 11 | cuprija
# Processing Record 13 of Set 11 | ribeira brava
# Processing Record 14 of Set 11 | toktogul
# Processing Record 15 of Set 11 | cortez
# Processing Record 16 of Set 11 | guerrero negro
# Processing Record 17 of Set 11 | urangan
# Processing Record 18 of Set 11 | rikaze
# Processing Record 19 of Set 11 | kapit
# Processing Record 20 of Set 11 | khandyga
# Processing Record 21 of Set 11 | montbard
# Processing Record 22 of Set 11 | apatity
# Processing Record 23 of Set 11 | taltal
# Processing Record 24 of Set 11 | kinango
# Processing Record 25 of Set 11 | sormiou
# City not found. Skipping...
# Processing Record 26 of Set 11 | midvagur
# Processing Record 27 of Set 11 | vila velha
# Processing Record 28 of Set 11 | bayan nur
# City not found. Skipping...
# Processing Record 29 of Set 11 | nguti
# Processing Record 30 of Set 11 | tirat karmel
# Processing Record 31 of Set 11 | coahuayana de hidalgo
# Processing Record 32 of Set 11 | loudeac
# Processing Record 33 of Set 11 | labrador city
# Processing Record 34 of Set 11 | ouellah
# City not found. Skipping...
# Processing Record 35 of Set 11 | yangor
# City not found. Skipping...
# Processing Record 36 of Set 11 | ryotsu-minato
# Processing Record 37 of Set 11 | altinekin
# Processing Record 38 of Set 11 | san giovanni rotondo
# Processing Record 39 of Set 11 | nova vicosa
# Processing Record 40 of Set 11 | sergeyevka
# Processing Record 41 of Set 11 | elista
# Processing Record 42 of Set 11 | merizo village
# Processing Record 43 of Set 11 | al ghayzah
# Processing Record 44 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 11 | magadan
# Processing Record 46 of Set 11 | nizhnesortymskiy
# Processing Record 47 of Set 11 | youghal
# Processing Record 48 of Set 11 | fort st. john
# Processing Record 49 of Set 11 | acapulco de juarez
# Processing Record 0 of Set 12 | las tablas
# Processing Record 1 of Set 12 | lompoc
# Processing Record 2 of Set 12 | cill airne
# Processing Record 3 of Set 12 | pangody
# Processing Record 4 of Set 12 | linxia chengguanzhen
# Processing Record 5 of Set 12 | barentu
# Processing Record 6 of Set 12 | sao paulo de olivenca
# Processing Record 7 of Set 12 | bacon
# Processing Record 8 of Set 12 | abepura
# Processing Record 9 of Set 12 | rabo de peixe
# Processing Record 10 of Set 12 | baienfurt
# Processing Record 11 of Set 12 | plettenberg bay
# Processing Record 12 of Set 12 | vega de alatorre
# Processing Record 13 of Set 12 | walvis bay
# Processing Record 14 of Set 12 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 15 of Set 12 | ghat
# Processing Record 16 of Set 12 | hassi messaoud
# Processing Record 17 of Set 12 | salekhard
# Processing Record 18 of Set 12 | cambria
# Processing Record 19 of Set 12 | prince albert
# Processing Record 20 of Set 12 | douglas
# Processing Record 21 of Set 12 | east london
# Processing Record 22 of Set 12 | amursk
# Processing Record 23 of Set 12 | les anglais
# Processing Record 24 of Set 12 | isna
# Processing Record 25 of Set 12 | arrifes
# Processing Record 26 of Set 12 | hovd
# Processing Record 27 of Set 12 | joshimath
# Processing Record 28 of Set 12 | mahalapye
# Processing Record 29 of Set 12 | at-bashi
# Processing Record 30 of Set 12 | hongwon
# Processing Record 31 of Set 12 | naze
# Processing Record 32 of Set 12 | mili
# Processing Record 33 of Set 12 | coalinga
# Processing Record 34 of Set 12 | dudinka
# Processing Record 35 of Set 12 | rwamagana
# Processing Record 36 of Set 12 | castillos
# Processing Record 37 of Set 12 | new norfolk
# Processing Record 38 of Set 12 | hanover
# Processing Record 39 of Set 12 | gisborne
# Processing Record 40 of Set 12 | al muwayh
# Processing Record 41 of Set 12 | sligo
# Processing Record 42 of Set 12 | amasra
# Processing Record 43 of Set 12 | llallagua
# Processing Record 44 of Set 12 | caconda
# Processing Record 45 of Set 12 | biasca
# Processing Record 46 of Set 12 | komsomol'skiy
# Processing Record 47 of Set 12 | ajdabiya
# Processing Record 48 of Set 12 | mirnyy
# Processing Record 49 of Set 12 | kencong
# Processing Record 0 of Set 13 | smach mean chey
# City not found. Skipping...
# Processing Record 1 of Set 13 | st. john's
# Processing Record 2 of Set 13 | la libertad
# Processing Record 3 of Set 13 | marat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness
# 0          cobija -11.0267  -68.7692     76.89        80          73  \
# 1           lihue  21.9789 -159.3672     79.84        72          75
# 2          albany  42.6001  -73.9662     43.57        46           2
# 3          bethel  41.3712  -73.4140     50.65        50           0
# 4  ribeira grande  38.5167  -28.7000     62.78        89          68
#
#    Wind Speed Country        Date
# 0        3.44      BO  1684375455
# 1       13.80      US  1684375455
# 2        4.81      US  1684375245
# 3        0.00      US  1684375455
# 4        5.99      PT  1684375456

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness
# City_ID
# 0                cobija -11.0267  -68.7692     76.89        80          73  \
# 1                 lihue  21.9789 -159.3672     79.84        72          75
# 2                albany  42.6001  -73.9662     43.57        46           2
# 3                bethel  41.3712  -73.4140     50.65        50           0
# 4        ribeira grande  38.5167  -28.7000     62.78        89          68
#
#          Wind Speed Country        Date
# City_ID
# 0              3.44      BO  1684375455
# 1             13.80      US  1684375455
# 2              4.81      US  1684375245
# 3              0.00      US  1684375455
# 4              5.99      PT  1684375456

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], facecolor="steelblue", edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], facecolor="steelblue", edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], facecolor="steelblue", edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], facecolor="steelblue", edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
        
        # Run regression on hemisphere weather data
        (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
        
        # Calculate the regression line "y values" from the slope and intercept
        regress_values = x_values * slope + intercept
        
        # Get the equation of the line
        line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

        # Create a scatter plot and plot the regression line
        plt.scatter(x_values,y_values)
        plt.plot(x_values,regress_values,"r")

        # Annotate the text for the line equation and add its coordinates
        plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
        plt.xlabel('Latitude')
        plt.ylabel(y_label)
        plt.title(title)
        plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness
# City_ID
# 1                 lihue  21.9789 -159.3672     79.84        72          75  \
# 2                albany  42.6001  -73.9662     43.57        46           2
# 3                bethel  41.3712  -73.4140     50.65        50           0
# 4        ribeira grande  38.5167  -28.7000     62.78        89          68
# 5             polyarnyy  69.1989   33.4478     39.99        97         100
#
#          Wind Speed Country        Date
# City_ID
# 1             13.80      US  1684375455
# 2              4.81      US  1684375245
# 3              0.00      US  1684375455
# 4              5.99      PT  1684375456
# 5             13.20      RU  1684375456

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness
# City_ID
# 0                   cobija -11.0267  -68.7692     76.89        80          73  \
# 6           puerto natales -51.7236  -72.4875     36.81        98         100
# 8                adamstown -25.0660 -130.1015     74.19        77           0
# 9        port-aux-francais -49.3500   70.2167     46.53        98         100
# 10                waitangi -43.9535 -176.5597     59.83        91         100
#
#          Wind Speed Country        Date
# City_ID
# 0              3.44      BO  1684375455
# 6              2.59      CL  1684375456
# 8              5.37      PN  1684375254
# 9             32.17      TF  1684375457
# 10             5.01      NZ  1684375457

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

# Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere for Maximum Temperature', 'Max Temp',(-50,80))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

# Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for % Humidity', '% Humidity',(40,10))

# %%
# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

# Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for % Humidity', '% Humidity',(-50,30))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

# Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for % Cloudiness', '% Cloudiness',(40,10))

# %%
# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

# Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-50,60))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

# Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed (mph)',(10,10))

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

# Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed (mph)',(-50,20))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
